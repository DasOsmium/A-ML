# %% [markdown]
# <a href="https://colab.research.google.com/github/DasOsmium/A-ML/blob/main/AML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
def enviornment():
  return 0

# %%
def agent():
  return 0

# %%
def visualize():
  return 0
